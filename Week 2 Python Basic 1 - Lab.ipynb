# %% [markdown]
# # 1.들어가기

# %% [markdown]
# ## 1.1 파이썬이란?
# 파이썬(Python)은 1991년 프로그래머인 귀도 반 로섬(Guido van Rossum)이 발표한 프로그래밍 언어
#
# 파이썬은 우리나라말로 '비단뱀'이란 뜻
#
# 2021년 10월 기준 프로그래밍 언어 인기 순위 2위(TIOBE Index)
# * 1위 C, 2위 Python, 3위 Java

# %% [markdown]
# ## 1.2 파이썬의 장점
#
# 문법이 쉽고 직관적이다.
#
# 코드가 읽기 좋다 (블록문으로 구성) -> 곧 배울 내용
#
# 다양한 운영체제 지원 (맥, 윈도우, 리눅스 등)
#
# 다양한 분야의 라이브러리가 활발히 개발 중
#
# > 특히 딥러닝/머신러닝, 데이터 분석, 웹 서비스

# %% [markdown]
# ## 1.3 파이썬으로 무엇을 할 수 있을까?
#
# 기초 통계 분석, 데이터 크롤링(스크래핑), 데이터 비쥬얼라이제이션, 소셜 네트워크 분석, 자연어 처리, 머신러닝, 딥러닝, 웹 서비스 개발, 데이터 전처리/분석, 수치 연산

# %% [markdown]
# ## 1.4 기초 파이썬 수업의 목표: 커피숍 키오스크 만들기
#
# ![키오스크.jpg](data:image/jpeg;base64,...)
#
# <h3>1. 메뉴판 만들기</h3>
# <h3>2. 주문 받기</h3>
# <h3>3. 주문 확인</h3>
# <h3>4. 가격 계산</h3>
# <h3>5. 결제</h3>

# %% [markdown]
# # 2.**출력, 문자열 (메뉴판 만들기)**
#
# 컴퓨터 화면에 무언가 원하는 것을 출력하기 위해서 파이썬은 `print()` 라는 명령어를 제공.
#
# `print()`의 괄호 안에 원하는 값을 넣고 출력해보자.

# %% [markdown]
# ## 2.1 출력 - `print()`
#
# 먼저 숫자부터 print

# %%
print(1)

# %% [markdown]
# 자연수, 정수, 실수 뭐든지 괄호 안에 넣고 입력하면 됨.

# %%
print(0.701)

# %% [markdown]
# 계산하고 싶은 값을 넣으면 계산까지 해준다.

# %%
print(3+4)

# %%
print(3.25*4.06)

# %% [markdown]
# ## 2.2 문자열
#
# 다음은 안녕하세요를 출력해보자.

# %%
print(안녕하세요)

# %% [markdown]
# 그런데 그냥 입력하면 에러가 . '안녕하세요'와 같이 "문자"를 입력할 때는 반드시 앞 뒤에 작은 따옴표(')나 큰 따옴표(")를 붙여주어야 함. 왜냐하면 따옴표를 붙여줘야지 컴퓨터는 이것이 **문자**라고 인식할 수 있기 때문. 그리고 '안녕하세요'와 같은 것을 **문자열**이라고 부른다.

# %%
print('안녕하세요')

# %% [markdown]
# 그럼 이제 배운 것을 이용해서 커피숍 키오스크의 메뉴판을 만들어보자.

# %% [markdown]
# ## 2.3 결과물
#
# 안녕하세요 스누카페입니다.
#
# 저희 카페에서 준비한 메뉴는 다음과 같습니다.
#
# ---------- 메뉴 ----------
#
# 아메리카노 1000원
#
# 카페라떼 1500원

# %%
print('안녕하세요 스누카페입니다.')
print('저희 카페에서 준비한 메뉴는 다음과 같습니다.')
print('---------- 메뉴 ----------')
print('아메리카노 1000원')
print('카페라떼  1500원')

# %% [markdown]
# # 3.입력 (주문 받기)

# %% [markdown]
# ## 3.1 입력 - `input()`
#
# 앞 단계에서는 숫자나 문자열을 '출력'하는 방법을 배웠다. 그렇다면 컴퓨터에게 무엇인가를 '입력'하려면 어떻게 해야할까?
#
# 예를 들어 음료를 주문할 때 사람들은 '아메리카노' 또는 '카페라떼'라고 이야기 한다. 이 내용 입력받으려면 어떻게 해야할까?
#
# 사용자로부터 무언가를 입력받고 싶으면 `input()`을 사용한다. `input()`이라고 괄호안에 아무것도 안써도 입력이 가능하다.

# %%
input()

# %% [markdown]
# ## 3.2 입력과 문자열
#
# 우린 그냥 아메리카노라고 입력했는데, 컴퓨터는 '아메리카노'라고 인식했다. 왜 그랬을까? 입력된 데이터의 형태가 바로 앞에서 배운 **문자열** 이기 때문. 따라서 컴퓨터는 입력 받은 모든 값을 기본적(default)으로 문자열로 인식한다는 것을 알 수 있다. 따라서 문자를 입력한다고 굳이 따옴표로 감쌀 필요가 없다.
#
# 그렇다면 숫자는?

# %%
input()

# %% [markdown]
# 원하는 아무 숫자나 입력해도 앞뒤로 작은따옴표(')가 붙은 것을 확인할 수 있다. 숫자도 무조건 문자열로 인식한다. 따라서 숫자를 입력하고 싶다면 입력된 '문자열 숫자'를 숫자로 변환해주어야 한다. 나중에 자세히 살펴보자.
#
# 이제 `input()`을 이용해서 주문을 받아보자.

# %% [markdown]
# ## 3.3 결과물1
#
# 키오스크(출력): 무엇을 주문하시겠어요?
#
# 사용자(입력)
#
# 키오스크(출력): 몇 잔 드릴까요?
#
# 사용자(입력)

# %%
print('무엇을 주문하시겠습니까?')
input()
print('몇 잔 드릴까요?')
input()

# %% [markdown]
# ## 3.4 입력 옵션
#
# `print()`는 괄호 안에 무언가를 넣으면 그 숫자를 출력했다. `input()`은 어떨까?

# %%
input(1)

# %% [markdown]
# 1이 먼저 출력되고 그 옆에 입력하는 칸(prompt)이 나타난다.
#
# 그럼 `print()`로 문자열을 출력하고 입력을 받을 필요없이 `input()`안에 우리가 원하는 문장을 넣으면 그 문장이 출력이 될 것이다.
#
# 다음과 같이 바꿔보자.

# %%
input('무엇을 주문하시겠습니까?')

# %% [markdown]
# 코드 2줄이 1줄로 줄었다.
#
# 그런데 '주문하시겠습니까?' 라는 문장 바로 옆에 빈칸도 없이 입력 프롬프트가 뜨는게 보기 흉하게 느껴진다.
#
# 스페이스를 넣어 띄어쓰기를 추가하거나, 줄바꿈을 해주는 방법으로 출력 레이아웃을 바꿔 줄 수 있다.

# %%
input('무엇을 주문하시겠습니까? ')

# %% [markdown]
# 줄바꿈을 하려면 어떻게 하면 될까?

# %%
input('무엇을 주문하시겠습니까?
')

# %% [markdown]
# 에러가 발생.
# 파이썬은 한줄의 코드를 읽고 해석하여 처리하는 방식으로 작동된다. 위의 예는 코드를 첫번째 줄의 코드가 완벽하게 마무리가 되지 않아서 에러가 발생한다.
#
# 그래서 다른 방법을 써야 하는데, '\n'이라고 끝에 입력해준다.

# %%
input('무엇을 주문하시겠습니까?\n')

# %% [markdown]
# '\n'과 같은 것을 Escape character라고 부른다.
#
# 비슷하게 다른 것도 해볼 수 있다. 띄어쓰기를 많이 하고 싶은 경우에는 워드프로세서에서 처럼 tab을 입력할 수 있다.

# %%
input('무엇을 주문하시겠습니까? ')

# %% [markdown]
# 좀 더 멀리 띄우고 싶어서 탭을 여러번 누른다.

# %%
input('무엇을 주문하시겠습니까?     ')

# %% [markdown]
# 이것을 Escape Character를 사용하려 해결할 수도 있다. 앞의 '\n'에서 n은 newline의 줄임말이다.
#
# 그럼 탭은? tab의 첫자를 따서 '\t' 라고 입력한다.

# %%
input('무엇을 주문하시겠습니까?\t')

# %% [markdown]
# 만약에 따옴표를 그대로 문자열 앞뒤에 넣고 싶으면 어떻게 해야할까?
#
# `'무엇을 주문하시겠습니까?'` 라는 문장을 출력하기 위해 문자열인 `''무엇을 준비하시겠습니까?''` 를 입력해보자.

# %%
input(''무엇을 주문하시겠습니까?'')

# %% [markdown]
# 에러가 발생. 해결하려면 두가지 방법이 있는데, 첫번째 방법은 큰따옴표(")를 이용하는 것.

# %%
input("'무엇을 주문하시겠습니까?'")

# %% [markdown]
# 문자열은 큰 따옴표와 작은 따옴표를 이용해서 만들 수 있다고 했는데, 큰 따옴표로 작은 따옴표를 감싸서 해결할 수 있다.
#
# 두 번째는 escape character를 이용하는 방법. \'를 쓰면 따옴표를 입력할 수 있다.

# %%
input('\'무엇을 주문하시겠습니까\'')

# %% [markdown]
# ## 3-5 결과물2

# %%
print('무엇을 주문하시겠습니까?')
input()
print('몇 잔 드릴까요?')
input()

# %%
input('무엇을 주문하시겠습니까?\n')
input('몇 잔 드릴까요?\n')

# %% [markdown]
# #4.변수 사용하기 (메뉴 확인하기)
#
# 2단계에서 주문을 입력받았고, 이번에는 진짜 카페에 직원처럼 주문받은 내역을 확인하는 것을 만들어보자.
#
# 그렇기 위해서는 사용자가 입력한 것을 어디에 남겼다가 다시 출력해야 한다. 즉, "저장"했다가 출력해야한다.
#
# 무언가를 저장하기 위해서는 "변수"를 사용한다. 변수는 값이 저장되는 일종의 저장소이다. 변수가 생성되면, 그 안에 저장된 값은 프로그램이 실행되는 동안 계속 유지된다.
#
# 파이썬에서 변수는 그냥 영문으로 변수 이름만 지정해주고 '='으로 값을 넣어주면 된다.
#
# ex) order = '아메리카노'

# %% [markdown]
# ## 4.1 변수

# %%
luckynumber = 7

# %% [markdown]
# 이전에는 뭔가를 출력할 때 print() 문 안에 출력할 내용을 그대로 써서 출력했다면 이제는 변수를 이용해서 보다 프로그램답게 만들어 보자.

# %%
print(luckynumber)

# %% [markdown]
# 아니 그냥 7로 간단히 입력하면 되는데 그걸 굳이 변수로 저장해서 출력해야할까?
#
# 문장을 반복적으로 출력한다면 변수를 이용하는 것이 편리하다.

# %%
print('무엇을 주문하시겠습니까?')
print('무엇을 주문하시겠습니까?')

# %%
order = '무엇을 주문하시겠습니까?'
print(order)
print(order)

# %% [markdown]
# 이렇게 직접 매번 같은 값을 입력해서 쓰는 것을 Hard coding이라고 부르고, 변수를 선언해 프로그래밍 하는 것을 Soft coding이라고 한다.
#
# Soft coding이라고 해도 10번을 매번 입력해서 출력해야 할까?
#
# 반복되는 작업을 해결하기 위한 반복문 (for loop)을 사용하면 된다. 뒤에서 자세히 다룰 예정.
#
# 그럼 이제 우리가 원하는 주문 확인을 해보자.

# %% [markdown]
# 주문 확인을 위해서는 주문 받은 결과를 변수로 저장해야.
#
# 변수로 저장하는 방법은 '='의 왼쪽에는 변수 이름을, 오른쪽에는 변수에 담을 내용을 입력.

# %%
menu = input('무엇을 주문하시겠습니까?\n')

# %% [markdown]
# 그럼 먼저 주문 받은 메뉴를 출력해서 확인해보자.
#
# 변수 안에 문자열이 저장되어 있어도, 변수를 출력할 때는 따옴표 없이 print() 괄호안에 그냥 넣어주면 된다.

# %%
menu = input('무엇을 주문하시겠습니까?\n')
print('주문하신 음료는')
print(menu)
print('입니다.')

# %% [markdown]
# ## 4.2 출력 옵션
#
# 여기서
# ```
# 주문하신 음료는
# 아메리카노
# 입니다.
# ```
# 와 같이 표시된 것이 별로 보기 좋지 않다. 세 줄의 문자열을 한줄로 만들어주고 싶다.
#
# 이런 문제를 해결하기 위해서는 출력 `print()`의 옵션을 변경해주면 다.
#
# `print()`는 기본적으로 출력할 때 마지막에 줄바꿈을 하도록 설정되어 있다.
#
# 이것을 줄바꿈이 아닌 띄어쓰기로 바꾸고 싶다면 `print()` 안에 `,end=' '` 옵션을 넣어준다.

# %%
menu = input('무엇을 주문하시겠습니까?\n')
print('주문하신 음료는', end=' ')
print(menu, end=' ')
print('입니다.')

# %% [markdown]
# 아메리카노 입니다를 아메리카노입니다로 붙여쓰고 싶다면? 띄어쓰기를 없애준다.
#
# `'  '` 대신 `''` 을 입력하면 된다.

# %%
menu = input('무엇을 주문하시겠습니까?\n')
print('주문하신 음료는', end=' ')
print(menu, end='')
print('입니다.')

# %% [markdown]
# ## 4.3 결과물1
#
#
# 자 그럼 이번에는 몇 잔을 주문 받을지 입력 받아 보자.
#
# `몇 잔을 드릴까요?`라고 묻고, 잔수를 amount라는 변수에 저장해보자.

# %%
menu = input('무엇을 주문하시겠습니까?\n')
amount = input('몇 잔 드릴까요?\n')

# %% [markdown]
# 변수로 저장한 값을 이용해서 주문 받은 메뉴를 다음과 같이 출력하여 확인해 보자.
#
# `'아메리카노 2잔 준비하겠습니다'`

# %%
print(menu amount '잔 준비하겠습니다.')

# %% [markdown]
# ## 4.4 출력과 문자열
#
# 위의 코드처럼 menu랑 amount를 그냥 함께 넣어버리면 에러가 발생한다. 그럼 다른 방법은? 변수가 2개니까 쉼표로 연결해보자.

# %%
print(menu, amount '잔 준비하겠습니다.')

# %% [markdown]
# 여전히 에러가 발생. amount와 뒤의 문자열 사이에도 쉼표가 필요하다.

# %%
print(menu, amount, '잔 준비하겠습니다.')

# %% [markdown]
# 원하는 결과가 출력.
#
# 그런데, 이렇게 쉼표 말고 다른 방법으로 출력하는 방법도 있다.
#
# 변수에 저장된 값은 모두 문자열이다.
#
# 파이썬은 문자열처리가 쉬운 것으로 매우 유명한 언어.
#
# 문자열끼리 연결할 때 '+'를 쓰면 된다.
#
# 'Python', '강의', '이준환'이라는 단어가 있을 때, 이것을 하나의 문자열 'Python 강의 이준환'으로 연결하고 싶으면 그냥 다 더하기로 연결하면 된다.

# %%
print('python' + '버전' + '3.9')

# %% [markdown]
# 띄어 쓰기가 없어서 보기가 불편하다. 어떻게 할까?
#
# 중간중간 띄어쓰기를 넣어주거나 공백(space)를 역시 중간에 더해주면 된다.

# %%
print('python ' + '버전 ' + '3.9')

# %%
print('python' + ' ' + '버전' + ' ' + '3.9')

# %% [markdown]
# 그럼 다시 커피숍 키오스크로 돌아와서 `'아메리카노 2잔 준비하겠습니다.'`를 출력해보자.

# %%
print(menu + amount + '잔 준비하겠습니다.')

# %% [markdown]
# 띄어쓰기가 필요하다면,

# %% [markdown]
# ## 4.6 결과물2
# 아메리카노 2잔 준비하겠습니다.

# %%
print(menu + ' ' + amount + '잔 준비하겠습니다.')

# %% [markdown]
# ## 4.7 프로그래머들이 좋아하는 방식
#
# 지금까지 변수를 이용해 원하는 형태로 결과물을 출력하는 방법을 살펴보았는데, 사실 프로그래머들은 다음과 같은 방법을 선호한다.
#
# 출력하고자 하는 문자열 안에 데이터(변수)가 들어갈 자리를 `{}` 로 마련해두고 뒤에 `.format()` 이라는 함수를 사용하여 어떤 변수가 들어갈 것인지 순서대로 선언해주는 것.

# %%
print('{} {}잔 준비하겠습니다.'.format(menu, amount))

# %% [markdown]
# #5.사칙연산, 변수종류 (가격 계산하기)
#
# 3단계에서 주문을 확인했다면 이번에는 사용자가 낼 금액이 얼마인지 계산해보자.
#
# 아까 1단계에서 살펴본 바와 같이 print(2+3)처럼 숫자의 계산은 그다지 어렵지 않다.
#
# 먼저 위에서 주문한 메뉴와 수량이 변수에 잘 저장되어 있는지 `print()`로 확인해보자.

# %%
print(menu)
print(amount)

# %% [markdown]
# ## 5.1 문자열 연산
#
# `'주문하신 menu의 가격은 총 1000 * amount 원 입니다'` 라고 출력을 하고 싶다.
#
# `print()`를 이용하여 확인해보자.

# %%
print('주문하신 메뉴의 가격은 총 ' + 1000 * amount + '원 입니다.')

# %% [markdown]
# 결과가 의도한대로 출력되지 않았다. 2000원이 출력이 되어야 하는데 2가 1000번 찍혔기 때문이다.
#
# amount는 `input()`으로 받은 문자열이어서 amount * 1000 은 숫자의 연산이 아닌, 문자열의 연산이기 때문.
#
# 문자열과 숫자의 연산은 그 수만큼 반복하게 해준다.
#
# 박수를 10번 출력해보자.

# %%
print('박수박수박수박수박수박수박수박수박수박수')
print('박수'*10)

# %% [markdown]
# ## 5.2 변수 종류 (숫자, 문자열)
#
# '2'와 2는 다르기 때문에 '2'를 숫자처럼 연산을 하기 위해서는 문자열을 숫자로 바꿔주어야 한다.
#
# 문자열을 숫자로 바꾸고 싶으면 변수 앞에 int를 붙이고 괄호안에 넣어준다.
# `int(amount)`
#
# 이런 것을 데이터의 타입을 변경해준다고 하는데, **형변환** 혹은 **type casting** 이라고 부른다.
#
# 형변환을 하지 않는다면 다음의 결과는 어떻게 출력이 될까?
#
# `"12" + "34"`

# %%
print(12+34)
print("12"+"34")

# %% [markdown]
# ## 5.3 변수 종류 변경 (문자열 -> 숫자)
#
# 다시 커피숍 키오스크로 돌아와서, `int()`로 데이터 타입을 변경하고 출력해보자. 여기서 int는 integer 즉, 정수의 약자.

# %%
print('주문하신 메뉴의 가격은 ' + 1000 * int(amount) + '원 입니다.')

# %% [markdown]
# 그러나 또 에러가 발생. 숫자의 연산은 잘 이루어졌지만 숫자와 문자열이 데이터 타입이 달라 + 를 이용하여 더할 수가 없기 때문.

# %%
print(1+"1")

# %%
price = 1000 * int(amount)
print('주문하신 메뉴의 가격은 ' + price + '원 입니다.')

# %% [markdown]
# ## 5.4 변수 종류 변경 (숫자 -> 문자열)
#
# 위의 예에서 price의 데이터 타입은 숫자이기 때문에 문자열과 더할 수가 없어서 에러가 발생. 그렇다면 숫자형을 문자열로 바꾸어 주어야 한다.
#
# `int()`처럼 문자열로 형변환을 하기 위해서는 `str()`을 사용한다. `str()`은 string, 즉 문자열의 줄임말이다.

# %%
price = 1000 * int(amount)
print('주문하신 메뉴의 가격은 ' + str(price) + '원 입니다.')

# %% [markdown]
# ## 5.5 프로그래머가 선호하는 방식으로 다시 출력
#
# 아까 위에서 배운대로 프로그래머들이 선호하는 방식으로 위의 문제를 다시 출력해보자. `format()`은 변수의 타입이 서로 달라도 문제없이 출력을 한다는 장점이 있다.

# %%
price = 1000 * int(amount)
print('주문하신 메뉴의 가격은 {}원 입니다.'.format(price))

# %% [markdown]
# #6.조건문, 인덴트(결제하기)
#
# 이전 단계에서 키오스크는 주문한 메뉴의 가격을 알려줬다. 이제 고객이 돈을 내는 과정을 만들어보자.
#
# 실제로 돈을 지불하는 것까지 만들 수는 없으니 지불 수단이 카드인지 현금인지를 물어보고 상황에 따라 지불 방법을 적절히 다르게 안내하는 것을 만들 것이다

# %% [markdown]
# ## 6.1 조건문 (if)
#
# 카드인지 현금인지에 따라 다른 결과를 보여줄 때는 조건문(conditional statement)을 사용한다. 조건문은 프로그램에서 '분기'를 만들어준다. 분기란 주어진 조건에 따라 다른 결과를 보여주는 것을 얘기한다.
#
# 가장 대표적인 `if statement`를 이용하여 조건문을 만들어 보자.
#
# `if statement`은 **조건**과 **실행문**이 필요하다.

# %%
if (조건) :
  실행

# %% [markdown]
# 조건문은 **조건(condition)**은 수학의 논리 관계를 이용하여 참과 거짓이 명확해야 한다.
# ```
# 1. a랑 b가 같다: a == b
# 2. a랑 b가 같지 않다: a != b
# 3. a가 b보다 크다: a > b
# 4. a가 b보다 작다: a < b
# 5. a가 b보다 크거나 같다: a >= b
# 6. a가 b보다 작거나 같다: a <= b
# ```
#
# if 문의 예시를 하나 들어보자.

# %%
amount = 4
if amount > 2:
  print("a) 캐리어가 필요하신가요?")

amount = 2
if amount > 2:
  print("b) 캐리어가 필요하신가요?")

# %% [markdown]
# ## 6.2 조건문 유형2
#
# 조건문은 하나 이상의 조건도 다룰 수 있다.
#
# 이럴 때, if와 else문을 사용한다.

# %%
where = input('매장에서 드시고 가시나요?\n')
if where == '네':
  print('QR 코드 체크인 또는 서명부 작성 부탁드립니다.')
else:
  print('1회용 컵에 준비해드리겠습니다.')

# %% [markdown]
# ## 6.3 조건문 유형3
#
# 만약에 조건이 두개 이상이라면 어떻게 해야할까?
#
# 그럴 때는 if, elif, else를 사용한다.

# %%
bean = input('어떤 원두로 준비해드릴까요?\n')
if bean == 'Jazz':
  print('Jazz 원두로 준비해드리겠습니다.')
elif bean == 'Mono':
  print('Mono 원두로 준비해드리겠습니다.')
elif bean == 'Cello':
  print('Cello 원두로 준비해드리겠습니다.')
else:
  print('한 번만 다시 말씀해주시겠어요?')

# %% [markdown]
# ## 6.4 결과물
#
# 그럼 이제까지 배운 것을 적용해서 결제 방법에 따라 다르게 안내하는 커피숍 키오스크를 만들어보자.

# %% [markdown]
# ```
# > (키오스크) 결제는 어떻게 도와드릴까요?
# > (사용자) 카드
# > (키오스크) 카드리더기에 카드를 넣어주세요.
# ```
# 또는
# ```
# > (키오스크) 결제는 어떻게 도와드릴까요?
# > (사용자) 현금
# > (키오스크) 투입구에 현금을 넣어주세요.
# ```

# %%
payment = input('결제는 어떻게 도와드릴까요?\n')
if payment == '카드':
  print('카드리더기에 카드를 넣어주세요.')
else:
  print('투입구에 현금을 넣어주세요 ')

# %% [markdown]
# ## 6.5 블록(인덴트)
#
# if문을 쓰면서 보니 위에서 작성했던 코드들과는 조금 다른 부분이 보인다.
#
# 코랩이 자동으로 해줘서 인지하기 어려웠을 수도 있는데, if문 안에 실행문이 살짝 안쪽으로 들여쓰기가 되어 있다.
#
# ### 매우 중요한 블록(인덴트,들여쓰기) 개념이 등장.
#
# if의 조건문 뒤에 :(콜론)이 있고 엔터를 치면 자연스럽게 안쪽으로 들여쓰기한채로 입력이 된다.
# 만약에 이렇게 들여쓰기가 안된다면 어떤 일이 발생할까?

# %%
bean = input('어떤 원두로 준비해드릴까요?\n')
if bean == 'Jazz':
print('Jazz 원두로 준비해드리겠습니다.')
elif bean == 'Mono':
  print('Mono 원두로 준비해드리겠습니다.')
elif bean == 'Cello':
  print('Cello 원두로 준비해드리겠습니다.')
else:
  print('한 번만 다시 말씀해주시겠어요?')

# %% [markdown]
# 에러메시지를 읽어보자.
#
# ###IndentationError: expected an indented block
#
# 인덴트된 블락을 기대했는데, 그게 안나와서 에러가 발생했다는 메시지.
#
# 파이썬은 이렇게 코드의 가독성을 높이고 코드블락의 시작과 끝을 알기 위해 인덴트 블록을 사용하는 것을 의무로 해두었음.

# %% [markdown]
# <h2>인덴트 블락의 개념은 매우 중요!!</h2>
#
# 코드를 작성하실 때 자동으로 들여쓰기가 안된다면 탭(Tab)키를 사용.
#
# 많이 사용하는 코드 에디터들은 코랩처럼 자동 들여쓰기를 해준다.
#
# 인덴테이션이 제대로 이루어져서 코드 실행에 에러는 발생하지 않았지만 아래 코드와 같이 잘못된 결과를 만들어낼 수도 있다.
#
# 아래의 코드의 문제는 무엇일까?

# %%
bean = input('어떤 원두로 준비해드릴까요?\n')
if bean == 'Jazz':
  print('Jazz 원두로 준비해드리겠습니다.')
elif bean == 'Mono':
  print('Mono 원두로 준비해드리겠습니다.')
elif bean == 'Cello':
  print('Cello 원두로 준비해드리겠습니다.')
else:
  print('한 번만 다시 말씀해주시겠어요?')
  print('결제는 어떻게 도와드릴까요?')

# %% [markdown]
# 원두를 결정하고 결제방법을 묻는 질문이 나와야 하는데 마지막 `print()`문이 출력되지 않았다. 이유는?
#
# 아래의 코드처럼 고쳐보자.

# %%
bean = input('어떤 원두로 준비해드릴까요?\n')
if bean == 'Jazz':
  print('Jazz 원두로 준비해드리겠습니다.')
elif bean == 'Mono':
  print('Mono 원두로 준비해드리겠습니다.')
elif bean == 'Cello':
  print('Cello 원두로 준비해드리겠습니다.')
else:
  print('한 번만 다시 말씀해주시겠어요?')
print('결제는 어떻게 도와드릴까요?')

# %% [markdown]
# 하지만 위의 코드도 문제가 있다.
#
# 원두의 종류를 알아듣지 못해 "한번만 다시 말씀해주시겠어요?" 라는 문장을 출력했는데 바로 결제방법에 대한 질문을 한다.
#
# 제대로 된 프로그램이라면 다시 한번 원두의 종류를 물었어야 한다.
#
# 이 문제는 조건문만으로는 해결하기가 어렵다. 다음 시간에 다룰 **반복문**을 이용해서 해결하기로 하고 여기서는 일단 넘어가자.

# %% [markdown]
# # 7.커피숍 키오스크 버전1
#
# 지금까지 커피숍 키오스크 만들어보았다.
#
# 이 프로그램은 완벽하지는 않지만, 입력함수와 변수, 조건문 등을 이용하여 실제 키오스크와 유사한 구조로 작동하였다.
#
# 사용된 전체 코드는 다음과 같다.

# %%
print('안녕하세요 스누카페입니다.')
print('저희 카페에서 준비한 메뉴는 다음과 같습니다.')
print('---------- 메뉴 ----------')
print('아메리카노 1000원')
print('카페라떼  1500원')

menu = input('무엇을 주문하시겠습니까?\n')
amount = input('몇 잔 드릴까요?\n')

print(menu + ' ' + amount + '잔 준비하겠습니다.')

price = 1000 * int(amount)
print('주문하신 메뉴의 가격은 ' + str(price) + '원 입니다.')

payment = input('결제는 어떻게 도와드릴까요?\n')
if payment == '카드':
  print('카드리더기에 카드를 넣어주세요.')
else:
  print('투입구에 현금을 넣어주세요 ')

# %% [markdown]
# ## 7.1 주석 (Comment)
#
# 코드가 길어지면 한 눈에 알아보기가 어렵다.
#
# 이럴 때 주석을 사용한다.
#
# 주석은 코드에서 **실행이 안되는 코드**로 보통 설명을 할 때 사용한다.

# %%
# 이 프로그램은 절대 실행되지 않는다
print("실행 되는데?")

# %% [markdown]
# 위의 코드에 주석을 넣어 프로그램의 가독성을 높여보자.

# %%
# 메뉴판
print('안녕하세요 스누카페입니다.')
print('저희 카페에서 준비한 메뉴는 다음과 같습니다.')
print('---------- 메뉴 ----------')
print('아메리카노 1000원')
print('카페라떼  1500원')

# 주문 받기
menu = input('무엇을 주문하시겠습니까?\n')
amount = input('몇 잔 드릴까요?\n')

# 주문 확인
print(menu + ' ' + amount + '잔 준비하겠습니다.')

# 가격 계산
price = 1000 * int(amount)
print('주문하신 메뉴의 가격은 ' + str(price) + '원 입니다.')

# 결제
payment = input('결제는 어떻게 도와드릴까요?\n')
if payment == '카드':
  print('카드리더기에 카드를 넣어주세요.')
else:
  print('투입구에 현금을 넣어주세요 ')

# %% [markdown]
# 주석은 디버깅을 할 때도 사용된다. 특정 코드에서 문제가 발생한 것처럼 보일 때 해당 부분의 코드를 주석처리 (comment out) 하고 실행하여 문제점을 찾곤 한다.

# %%
print("첫번째 문장")
#print("두번째 문장에서 에러" + 5 + "개가 발생하였다.")
print("세번째 문장은 괜찮네.")

# %% [markdown]
# ## 7.2 실습: 커피숍 키오스크 버전1.1 - 카페라떼 처리
#
# 위의 코드는 아메리카노(1000원) 만을 처리할 수 있었다.
#
# 만약 사용자가 카페라떼를 주문한다면 어떻게할까?
#
# 카페라떼 가격을 처리할 수 있도록 프로그램을 고쳐보자

# %%
# 위의 코드를 복사해서 카페라떼를 처리하는 코드를 추가해보자
